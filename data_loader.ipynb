# %% [markdown]
# Written by [Gameli Ladzekpo](mailto:gameli.Ladzekpo@gmail.com) (Twitter/IG: @gamladz)
#
# For [AI Core](theaicore.com)

# %%
import pandas as pd
import json
from ast import literal_eval
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd  
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# %%
# pd.options.display.max_columns = None
# pd.options.display.max_rows = None


# Read files into a dataframe
with open('DATA/data_json_1.txt', 'r') as fp:
    data1 = json.load(fp)

df = pd.DataFrame.from_dict({(i,j): data1[i][j] 
                           for i in data1.keys() 
                           for j in data1[i].keys()},
                       orient='index')


# Read files into a dataframe
with open('DATA/data_2.json', 'r') as fp:
    data2 = json.load(fp)

df = pd.DataFrame.from_dict({(i,j): data2[i][j] 
                           for i in data2.keys() 
                           for j in data2[i].keys()},
                       orient='index')


print(data, data2)

# # Clean_df will be used to save cleaned data
clean_df = pd.DataFrame()

# # https://stackoverflow.com/questions/50307707/convert-pandas-dataframe-to-pytorch-tensor
# Out:
# {'plant pots': {'0': {'id': 0, 'prod_name': 'MUSKOT', 'prod_price': '1', 'prod_desc': 'Plant pot, white', 'prod_dimensions': {'Height': '11 cm', 'Outside diameter': '12 cm', 'Max. diameter flowerpot': '9 cm', 'Inside diameter': '11 cm'}, 'packaging': ['MUSKOT', 'Plant pot', 'Article no.:', '303.082.01', 'Length: 11 cm', 'Weight: 0.39 kg', 'Diameter: 12 cm', 'Package(s): 1'], 'prod_details': 'Decorate your home with plants combined with a plant pot to suit your style. May be combined with the other plant pots in the MUSKOT series. To protect the surface from any risk of moisture damage, always use a plant mover or put felt pads under the plant pot or saucer.', 'sustainability': '', 'images': ['data/plant pots/muskot-plant-pot-white-30308201/muskot-plant-pot-white-30308201-0.JPG', 'data/plant pots/muskot-plant-pot-white-30308201/muskot-plant-pot-white-30308201-1.JPG', 'data/plant pots/muskot-plant-pot-white-30308201/muskot-plant-pot-white-30308201-2.JPG', 'data/plant pots/muskot-plant-
# ...
